# %% [markdown]
# # 공통
# - Weights : yolov5x.pt
# - models : yolov5x.yaml
# - img, batch, epochs : 416, 8, 50

# %% [markdown]
# ## Shoes
# - train : 333개
# - vaild : 107개
# - nc : 1개
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Vehicle
# - train : 439개
# - valid : 125개
# - nc : 5개
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Pistols
# - train : 2080개
# - valid : 593개
# - nc : 1개
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PlantDoc
# - train : 2028개
# - valid : 539개
# - nc : 30개
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Brackish Underwater - batch 4(메모리 부족)
# - train : 11739개
# - valid : 1467개
# ![image.png](attachment:image.png)
