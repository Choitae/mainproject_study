# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# loads and read an image from path to file
img = cv2.imread('data_new/IU.jpg')
img_yuv = cv2.cvtColor(img ,cv2.COLOR_BGR2YUV)
img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])
#print(img_new)
# displays previous image"""
img2 =cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)
cv2.imshow('image', img2 )
# keeps the window open until a key is pressed
cv2.waitKey(0)
# clears all window buffers
cv2.destroyAllWindows() #창으로 구현된다

# %%
 # loads and read an image from path to file
img = cv2.imread('data_new/IU.jpg')
img_yuv = cv2.cvtColor(img ,cv2.COLOR_BGR2YUV)
img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])
#print(img_new)
# displays previous image"""
img2 =cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
 # For easier view, turn off axis around image
 plt.axis('off')
 plt.show()

# %%
img.shape
# Out:
# (191, 340, 3)

# %%
 # loads and read an image from path to file
img = cv2.imread('data_new/shoes_1.jpg')
img_yuv = cv2.cvtColor(img ,cv2.COLOR_BGR2YUV)
img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])
#print(img_new)
# displays previous image"""
img2 =cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
 # For easier view, turn off axis around image
 plt.axis('off')
 plt.show()

# %%
 # loads and read an image from path to file
import numpy as np
import cv2
img = cv2.imread('data_new/shoes_1.jpg')
for i in range(len(img[:])) : 
    for j in range(len(img[i][:])):
        img_array = img[i][j]
        if np.all(img_array > 250) :
            img[i][j] = [0, 0, 0]
            
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
b = img[3][3]
if np.all(b==255) : 
    img[3][3] = [0, 0, 0]

print(img[3][3])
# Out:
# [0 0 0]

# %%
img[3][3] == [255,255,255]
# Out:
# array([ True,  True,  True])

# %%
for i in range(4)
# Out:
#   File "<ipython-input-6-3ed60b3be129>", line 1
#     for i in range(4)
#                      ^
# SyntaxError: invalid syntax

# %%
img = cv2.imread('data_new/shoes_1.jpg')
img_change = img // 2
plt.imshow(cv2.cvtColor(img_change, cv2.COLOR_BGR2RGB))
# For easier view, turn off axis around image
plt.axis('off')
plt.show()

# %%
img_yuv = cv2.cvtColor(img_change ,cv2.COLOR_BGR2YUV)
img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])

img2 =cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)
cv2.imwrite("data_new/check.jpg", img2)
"""plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
 # For easier view, turn off axis around image
plt.axis('off')
plt.show()"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a7b90a411bd2> in <module>
# ----> 1 img_yuv = cv2.cvtColor(img_change ,cv2.COLOR_BGR2YUV)
#       2 img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])
#       3
#       4 img2 =cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)
#       5 cv2.imwrite("data_new/check.jpg", img2)
#
# NameError: name 'img_change' is not defined

# %%
img_yuv
# Out:
# array([[[127, 128, 128],
#         [127, 128, 128],
#         [127, 128, 128],
#         ...,
#         [127, 128, 128],
#         [127, 128, 128],
#         [127, 128, 128]],
#
#        [[127, 128, 128],
#         [127, 128, 128],
#         [127, 128, 128],
#         ...,
#         [127, 128, 128],
#         [127, 128, 128],
#         [127, 128, 128]],
#
#        [[127, 128, 128],
#         [127, 128, 128],
#         [127, 128, 128],
#         ...,
#         [127, 128, 128],
#         [127, 128, 128],
#         [127, 128, 128]],
#
#        ...,
#
#        [[127, 128, 128],
#         [127, 128, 128],
#         [127, 128, 128],
#         ...,
#         [127, 128, 128],
#         [127, 128, 128],
#         [127, 128, 128]],
#
#        [[127, 128, 128],
#         [127, 128, 128],
#         [127, 128, 128],
#         ...,
#         [127, 128, 128],
#         [127, 128, 128],
#         [127, 128, 128]],
#
#        [[127, 128, 128],
#         [127, 128, 128],
#         [127, 128, 128],
# ...

# %%
shoes = cv2.imread('data_new/test_1.jpg')
plt.imshow(cv2.cvtColor(shoes, cv2.COLOR_BGR2RGB))
 # For easier view, turn off axis around image
plt.axis('off')
plt.show()

# %%
cv2.rectangle(shoes, (1162,928),(1860,1889),(255,0,0),5)
cv2.rectangle(shoes, (1773,304),(2511,1166),(255,0,0),5)
# Out:
# array([[[177, 185, 184],
#         [177, 185, 184],
#         [176, 184, 183],
#         ...,
#         [162, 171, 174],
#         [163, 172, 176],
#         [163, 172, 176]],
#
#        [[179, 187, 186],
#         [178, 186, 185],
#         [175, 183, 182],
#         ...,
#         [163, 172, 175],
#         [163, 172, 176],
#         [163, 172, 176]],
#
#        [[182, 187, 188],
#         [180, 185, 186],
#         [175, 183, 183],
#         ...,
#         [162, 171, 175],
#         [162, 171, 175],
#         [161, 170, 174]],
#
#        ...,
#
#        [[183, 188, 191],
#         [183, 188, 191],
#         [184, 189, 192],
#         ...,
#         [ 72,  79,  82],
#         [ 74,  81,  84],
#         [ 75,  82,  85]],
#
#        [[182, 187, 190],
#         [182, 187, 190],
#         [183, 188, 191],
#         ...,
#         [ 75,  82,  85],
#         [ 76,  83,  86],
#         [ 75,  82,  85]],
#
#        [[183, 188, 191],
#         [182, 187, 190],
#         [182, 187, 190],
# ...

# %%
plt.imshow(cv2.cvtColor(shoes, cv2.COLOR_BGR2RGB))
 # For easier view, turn off axis around image
plt.axis('off')
plt.show()

# %%
x, y = 
a = np.zeros((x,y,3), dtype = np.uint8)

# %%
shoes.shape
# Out:
# (1920, 4032, 3)

# %%
for i, img_1 in enumerate(range(928, 1162)):
    for j, img_2 in enumerate(range(928, 1889)):
        for k in range(3):
            a[i][j][k] = shoes[img_1][img_2][k]

# %%
print(a)
# Out:
# [[[219 224 227]
#   [219 224 227]
#   [217 222 225]
#   ...
#   [146 153 156]
#   [144 151 154]
#   [147 152 153]]
#
#  [[216 221 224]
#   [217 222 225]
#   [215 220 223]
#   ...
#   [150 157 160]
#   [148 155 158]
#   [152 157 158]]
#
#  [[213 218 221]
#   [214 219 222]
#   [213 218 221]
#   ...
#   [154 159 162]
#   [154 159 162]
#   [158 163 166]]
#
#  ...
#
#  [[175 181 186]
#   [174 180 185]
#   [174 180 185]
#   ...
#   [137 149 155]
#   [139 151 157]
#   [141 155 161]]
#
#  [[177 183 188]
#   [178 184 189]
#   [177 183 188]
#   ...
#   [136 148 154]
#   [140 152 158]
#   [139 153 159]]
#
#  [[180 186 191]
#   [179 185 190]
#   [179 185 190]
#   ...
#   [135 147 153]
#   [139 151 157]
#   [137 151 157]]]

# %%
plt.imshow(cv2.cvtColor(a, cv2.COLOR_BGR2RGB))
 # For easier view, turn off axis around image
plt.axis('off')
plt.show()

# %%
type(a)
# Out:
# numpy.ndarray

# %%
for i, img_1 in enumerate(range(10, 14)):
    for j, img_2 in enumerate(range(10, 15)):
        for k in range(3):
            print(i, j, k)
            print(img_1, img_2, k)
            print("="*8)
# Out:
# 0 0 0
# 10 10 0
# ...
# 0 0 1
# 10 10 1
# ...
# 0 0 2
# 10 10 2
# ...
# 0 1 0
# 10 11 0
# ...
# 0 1 1
# 10 11 1
# ...
# 0 1 2
# 10 11 2
# ...
# 0 2 0
# 10 12 0
# ...
# 0 2 1
# 10 12 1
# ...
# 0 2 2
# 10 12 2
# ...
# 0 3 0
# 10 13 0
# ...
# 0 3 1
# 10 13 1
# ...
# 0 3 2
# 10 13 2
# ...
# 0 4 0
# 10 14 0
# ...
# 0 4 1
# 10 14 1
# ...
# 0 4 2
# 10 14 2
# ...
# 1 0 0
# 11 10 0
# ...
# 1 0 1
# 11 10 1
# ...
# 1 0 2
# 11 10 2
# ...
# 1 1 0
# 11 11 0
# ...
# 1 1 1
# 11 11 1
# ...
# 1 1 2
# 11 11 2
# ...
# 1 2 0
# 11 12 0
# ...
# 1 2 1
# 11 12 1
# ...
# 1 2 2
# 11 12 2
# ...
# 1 3 0
# 11 13 0
# ...
# 1 3 1
# 11 13 1
# ...
# 1 3 2
# 11 13 2
# ...
# 1 4 0
# 11 14 0
# ...
# 1 4 1
# 11 14 1
# ...
# 1 4 2
# 11 14 2
# ...
# 2 0 0
# 12 10 0
# ...
# 2 0 1
# 12 10 1
# ...
# 2 0 2
# 12 10 2
# ...
# 2 1 0
# 12 11 0
# ...
# 2 1 1
# 12 11 1
# ...
# 2 1 2
# 12 11 2
# ...
# 2 2 0
# 12 12 0
# ...
# 2 2 1
# 12 12 1
# ...
# 2 2 2
# 12 12 2
# ...
# 2 3 0
# 12 13 0
# ...
# 2 3 1
# 12 13 1
# ...
# 2 3 2
# 12 13 2
# ...
# 2 4 0
# 12 14 0
# ...
# 2 4 1
# 12 14 1
# ...
# 2 4 2
# 12 14 2
# ...
# 3 0 0
# 13 10 0
# ...
# 3 0 1
# 13 10 1
# ...
# 3 0 2
# 13 10 2
# ...
# 3 1 0
# 13 11 0
# ...
# 3 1 1
# 13 11 1
# ...
# 3 1 2
# 13 11 2
# ...
# 3 2 0
# 13 12 0
# ...
# 3 2 1
# 13 12 1
# ...
# 3 2 2
# 13 12 2
# ...
# 3 3 0
# 13 13 0
# ...
# 3 3 1
# ...

# %%
import cv2
 
im = cv2.imread('../../shoes/test/test_1.jpg')
 
img_new = cv2.rectangle(im, (1162,928),(1860,1889), (255,0,0), 3)
 
plt.imshow(img_new)

# %%
img_new.shape
# Out:
# (416, 416, 3)
